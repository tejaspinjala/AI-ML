# %% [markdown]
# ![insurance1.png](attachment:insurance1.png)

# %%
# x1, x2, x3, x4 are input layer
# x1 and x2 are hidden layer
# going backwards if wrong is backward propogation
# epoch is forward + backward propogation

# %% [markdown]
# ![insurance2.png](attachment:insurance2.png)

# %%
# dense because each input neuron is connected to every other neuron

# %% [markdown]
# ![NeuralNetworkDigit1.png](attachment:NeuralNetworkDigit1.png)

# %% [markdown]
# ![NeuralNetworkDigit2.png](attachment:NeuralNetworkDigit2.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

import tensorflow as tf
from tensorflow import keras
# Out:
# 2023-08-02 18:07:16.089965: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# %%
len(X_train)
# Out:
# 60000

# %%
len(X_test)
# Out:
# 10000

# %%
X_train[0].shape
# Out:
# (28, 28)

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
#X_train[0]

# %%
plt.matshow(X_train[0])

# %%
y_train[0]
# Out:
# 5

# %%
y_train[:10]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4], dtype=uint8)

# %%
X_train.shape[1]
# Out:
# 28

# %%
# (60000, 28, 28) to (60000, 784) NOT SCALING
X_train_flattened = X_train.reshape(len(X_train), X_train.shape[1] * X_train.shape[2])
X_test_flattened = X_test.reshape(len(X_test), X_test.shape[1] * X_test.shape[2])

# %%
print(X_train.shape)
print(X_train_flattened.shape)
# Out:
# (60000, 28, 28)
# (60000, 784)

# %%
#X_train[1]

# %%
#X_train_flattened[1]

# %%
X_train_flattened[10][12]
# Out:
# 0

# %%
X_train_flattened.shape[1]
# Out:
# 784

# %%
# Simple NN
# 10 is the output neurons
model = keras.Sequential([
    keras.layers.Dense(10, input_shape = (X_train_flattened.shape[1],), activation = 'sigmoid')
])

model.compile(
    optimizer = 'adam',
    loss = 'sparse_categorical_crossentropy',
    metrics = ['accuracy']
)

model.fit(X_train_flattened, y_train, epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 9.8635 - accuracy: 0.8415
# Epoch 2/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 6.0396 - accuracy: 0.8789
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 5.6343 - accuracy: 0.8832
# Epoch 4/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 5.5557 - accuracy: 0.8850
# Epoch 5/5
# 1875/1875 [==============================] - 3s 2ms/step - loss: 5.3728 - accuracy: 0.8884

# %%
model.evaluate(X_test_flattened, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 6.3412 - accuracy: 0.8781
# [6.341248035430908, 0.8780999779701233]
